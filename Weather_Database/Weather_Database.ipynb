# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the time library and the datetime module from the datetime library 
import time

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key# Make a 'Get' request for the city weather.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | chilakalurupet
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | ancud
# Processing Record 5 of Set 1 | aksu
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | koboldo
# City not found. Skipping...
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | tessalit
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | sitka
# Processing Record 17 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | avera
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | bowen
# Processing Record 26 of Set 1 | waddan
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | port hedland
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | eslov
# Processing Record 33 of Set 1 | caconda
# Processing Record 34 of Set 1 | mangan
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | santa rosa
# Processing Record 37 of Set 1 | pangnirtung
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | santa cruz
# Processing Record 41 of Set 1 | santa marta
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | hamilton
# Processing Record 44 of Set 1 | asau
# Processing Record 45 of Set 1 | port blair
# Processing Record 46 of Set 1 | jalu
# Processing Record 47 of Set 1 | pawa
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | praia da vitoria
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | nexo
# Processing Record 2 of Set 2 | ostrovnoy
# Processing Record 3 of Set 2 | floro
# Processing Record 4 of Set 2 | namibe
# Processing Record 5 of Set 2 | fortuna
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | ahipara
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | lokosovo
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | moron
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | kaitangata
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | lima
# Processing Record 19 of Set 2 | havre-saint-pierre
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | douglas
# Processing Record 22 of Set 2 | talaya
# Processing Record 23 of Set 2 | katav-ivanovsk
# Processing Record 24 of Set 2 | nizwa
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | tairua
# Processing Record 29 of Set 2 | kapiri mposhi
# Processing Record 30 of Set 2 | collierville
# Processing Record 31 of Set 2 | inirida
# Processing Record 32 of Set 2 | abu samrah
# Processing Record 33 of Set 2 | vestmanna
# Processing Record 34 of Set 2 | villa oliva
# City not found. Skipping...
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | tena
# Processing Record 37 of Set 2 | yerbogachen
# Processing Record 38 of Set 2 | atocha
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | sudak
# Processing Record 41 of Set 2 | puerto madryn
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | qinhuangdao
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | laguna
# Processing Record 46 of Set 2 | bukachacha
# Processing Record 47 of Set 2 | langxiang
# Processing Record 48 of Set 2 | naron
# Processing Record 49 of Set 2 | pisco
# Processing Record 50 of Set 2 | lucea
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | shingu
# Processing Record 3 of Set 3 | imbituba
# Processing Record 4 of Set 3 | kawalu
# Processing Record 5 of Set 3 | athabasca
# Processing Record 6 of Set 3 | mustasaari
# Processing Record 7 of Set 3 | sao jose da coroa grande
# Processing Record 8 of Set 3 | padang
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | ewa beach
# Processing Record 12 of Set 3 | naruto
# Processing Record 13 of Set 3 | shirgaon
# Processing Record 14 of Set 3 | olinda
# Processing Record 15 of Set 3 | marshall
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | sept-iles
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | east london
# Processing Record 21 of Set 3 | muros
# Processing Record 22 of Set 3 | tulle
# Processing Record 23 of Set 3 | cayenne
# Processing Record 24 of Set 3 | damaturu
# Processing Record 25 of Set 3 | maningrida
# Processing Record 26 of Set 3 | solnechnyy
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | znamenskoye
# Processing Record 29 of Set 3 | verkhoyansk
# Processing Record 30 of Set 3 | chuy
# Processing Record 31 of Set 3 | kaputa
# Processing Record 32 of Set 3 | shivrajpur
# Processing Record 33 of Set 3 | svetlaya
# Processing Record 34 of Set 3 | aklavik
# Processing Record 35 of Set 3 | pointe michel
# Processing Record 36 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 37 of Set 3 | phek
# Processing Record 38 of Set 3 | beisfjord
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | tres barras
# Processing Record 41 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 3 | aitape
# Processing Record 43 of Set 3 | nganjuk
# Processing Record 44 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 3 | aripuana
# Processing Record 46 of Set 3 | kabare
# Processing Record 47 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | mana
# Processing Record 50 of Set 3 | kahului
# Processing Record 1 of Set 4 | deputatskiy
# Processing Record 2 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 4 | mpika
# Processing Record 4 of Set 4 | saint-joseph
# Processing Record 5 of Set 4 | tibati
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | nanortalik
# Processing Record 9 of Set 4 | axim
# Processing Record 10 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 4 | payo
# Processing Record 12 of Set 4 | samarai
# Processing Record 13 of Set 4 | jamestown
# Processing Record 14 of Set 4 | victoria
# Processing Record 15 of Set 4 | grindavik
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | erzin
# Processing Record 18 of Set 4 | galesong
# Processing Record 19 of Set 4 | harper
# Processing Record 20 of Set 4 | rangapara
# Processing Record 21 of Set 4 | gopalpur
# Processing Record 22 of Set 4 | beryslav
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | bone
# Processing Record 27 of Set 4 | wenden
# Processing Record 28 of Set 4 | kalaleh
# Processing Record 29 of Set 4 | buchanan
# Processing Record 30 of Set 4 | olafsvik
# Processing Record 31 of Set 4 | paamiut
# Processing Record 32 of Set 4 | bredasdorp
# Processing Record 33 of Set 4 | dunedin
# Processing Record 34 of Set 4 | nueva guinea
# Processing Record 35 of Set 4 | yellowknife
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | ptichye
# Processing Record 38 of Set 4 | meulaboh
# Processing Record 39 of Set 4 | usagara
# Processing Record 40 of Set 4 | araouane
# Processing Record 41 of Set 4 | sao miguel do araguaia
# Processing Record 42 of Set 4 | strezhevoy
# Processing Record 43 of Set 4 | henties bay
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | la romana
# Processing Record 48 of Set 4 | kompaniyivka
# Processing Record 49 of Set 4 | kaili
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | lasa
# Processing Record 2 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 5 | qorveh
# Processing Record 4 of Set 5 | praia
# Processing Record 5 of Set 5 | markala
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | tamandare
# Processing Record 8 of Set 5 | kutum
# Processing Record 9 of Set 5 | maridi
# Processing Record 10 of Set 5 | mahebourg
# Processing Record 11 of Set 5 | santa isabel do rio negro
# Processing Record 12 of Set 5 | baruun-urt
# Processing Record 13 of Set 5 | arraial do cabo
# Processing Record 14 of Set 5 | coquimbo
# Processing Record 15 of Set 5 | dhidhdhoo
# Processing Record 16 of Set 5 | dali
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | carolina
# Processing Record 19 of Set 5 | margate
# Processing Record 20 of Set 5 | pevek
# Processing Record 21 of Set 5 | lahaina
# Processing Record 22 of Set 5 | christchurch
# Processing Record 23 of Set 5 | matamoros
# Processing Record 24 of Set 5 | puerto carreno
# Processing Record 25 of Set 5 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 26 of Set 5 | tiznit
# Processing Record 27 of Set 5 | nouadhibou
# Processing Record 28 of Set 5 | sandnessjoen
# Processing Record 29 of Set 5 | grand gaube
# Processing Record 30 of Set 5 | mar del plata
# Processing Record 31 of Set 5 | marsa matruh
# Processing Record 32 of Set 5 | newport
# Processing Record 33 of Set 5 | mogadishu
# Processing Record 34 of Set 5 | antalaha
# Processing Record 35 of Set 5 | mattawa
# Processing Record 36 of Set 5 | necochea
# Processing Record 37 of Set 5 | oriximina
# Processing Record 38 of Set 5 | lusambo
# Processing Record 39 of Set 5 | mudyuga
# City not found. Skipping...
# Processing Record 40 of Set 5 | nouakchott
# Processing Record 41 of Set 5 | saint george
# Processing Record 42 of Set 5 | fukuchiyama
# Processing Record 43 of Set 5 | bengkulu
# Processing Record 44 of Set 5 | mumford
# Processing Record 45 of Set 5 | constitucion
# Processing Record 46 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 5 | coahuayana
# Processing Record 48 of Set 5 | airai
# Processing Record 49 of Set 5 | bac lieu
# Processing Record 50 of Set 5 | luderitz
# Processing Record 1 of Set 6 | fort-shevchenko
# Processing Record 2 of Set 6 | inhambane
# Processing Record 3 of Set 6 | svetlyy
# Processing Record 4 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 6 | caravelas
# Processing Record 6 of Set 6 | sola
# Processing Record 7 of Set 6 | suntar
# Processing Record 8 of Set 6 | sume
# Processing Record 9 of Set 6 | ambunti
# Processing Record 10 of Set 6 | yala
# Processing Record 11 of Set 6 | sahuaripa
# Processing Record 12 of Set 6 | vanimo
# Processing Record 13 of Set 6 | bud
# Processing Record 14 of Set 6 | manali
# Processing Record 15 of Set 6 | komsomolets
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | cockburn town
# Processing Record 18 of Set 6 | los llanos de aridane
# Processing Record 19 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 6 | sinnamary
# Processing Record 21 of Set 6 | plouzane
# Processing Record 22 of Set 6 | lavrentiya
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | hurricane
# Processing Record 25 of Set 6 | kloulklubed
# Processing Record 26 of Set 6 | te anau
# Processing Record 27 of Set 6 | boyolangu
# Processing Record 28 of Set 6 | rio grande
# Processing Record 29 of Set 6 | emilio carranza
# Processing Record 30 of Set 6 | sonkovo
# Processing Record 31 of Set 6 | the valley
# Processing Record 32 of Set 6 | muzhi
# Processing Record 33 of Set 6 | murgud
# Processing Record 34 of Set 6 | eresos
# Processing Record 35 of Set 6 | rocha
# Processing Record 36 of Set 6 | mount isa
# Processing Record 37 of Set 6 | souillac
# Processing Record 38 of Set 6 | lebu
# Processing Record 39 of Set 6 | makat
# Processing Record 40 of Set 6 | qui nhon
# Processing Record 41 of Set 6 | geraldton
# Processing Record 42 of Set 6 | tiksi
# Processing Record 43 of Set 6 | ambon
# Processing Record 44 of Set 6 | wufeng
# Processing Record 45 of Set 6 | mweka
# Processing Record 46 of Set 6 | hami
# Processing Record 47 of Set 6 | thunder bay
# Processing Record 48 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 6 | komsomolskiy
# Processing Record 1 of Set 7 | flinders
# Processing Record 2 of Set 7 | taksimo
# Processing Record 3 of Set 7 | zabol
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | shimoda
# Processing Record 6 of Set 7 | oum hadjer
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | cabo san lucas
# Processing Record 9 of Set 7 | vila
# Processing Record 10 of Set 7 | moerai
# Processing Record 11 of Set 7 | dumka
# Processing Record 12 of Set 7 | vestmannaeyjar
# Processing Record 13 of Set 7 | oarai
# Processing Record 14 of Set 7 | patterson
# Processing Record 15 of Set 7 | imeni poliny osipenko
# Processing Record 16 of Set 7 | dzaoudzi
# Processing Record 17 of Set 7 | flin flon
# Processing Record 18 of Set 7 | plettenberg bay
# Processing Record 19 of Set 7 | xining
# Processing Record 20 of Set 7 | gallup
# Processing Record 21 of Set 7 | san luis
# Processing Record 22 of Set 7 | nadym
# Processing Record 23 of Set 7 | kavaratti
# Processing Record 24 of Set 7 | kavieng
# Processing Record 25 of Set 7 | hay river
# Processing Record 26 of Set 7 | tezu
# Processing Record 27 of Set 7 | fairbanks
# Processing Record 28 of Set 7 | buraydah
# Processing Record 29 of Set 7 | rognan
# Processing Record 30 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 7 | digoin
# Processing Record 32 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 7 | pimentel
# Processing Record 34 of Set 7 | berlevag
# Processing Record 35 of Set 7 | honningsvag
# Processing Record 36 of Set 7 | onega
# Processing Record 37 of Set 7 | arawa
# Processing Record 38 of Set 7 | yanam
# Processing Record 39 of Set 7 | catamarca
# Processing Record 40 of Set 7 | ganserndorf
# Processing Record 41 of Set 7 | phangnga
# Processing Record 42 of Set 7 | atasu
# Processing Record 43 of Set 7 | husavik
# Processing Record 44 of Set 7 | neustadt
# Processing Record 45 of Set 7 | whitehorse
# Processing Record 46 of Set 7 | port augusta
# Processing Record 47 of Set 7 | tual
# Processing Record 48 of Set 7 | bow island
# Processing Record 49 of Set 7 | hasaki
# Processing Record 50 of Set 7 | mezen
# Processing Record 1 of Set 8 | katsuura
# Processing Record 2 of Set 8 | mnogovershinnyy
# Processing Record 3 of Set 8 | ballina
# Processing Record 4 of Set 8 | dariba
# Processing Record 5 of Set 8 | tarko-sale
# Processing Record 6 of Set 8 | vytegra
# Processing Record 7 of Set 8 | ustye
# Processing Record 8 of Set 8 | abu dhabi
# Processing Record 9 of Set 8 | kununurra
# Processing Record 10 of Set 8 | yaan
# Processing Record 11 of Set 8 | hailar
# Processing Record 12 of Set 8 | tasiilaq
# Processing Record 13 of Set 8 | ryotsu
# Processing Record 14 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 8 | codrington
# Processing Record 16 of Set 8 | keffi
# Processing Record 17 of Set 8 | wageningen
# Processing Record 18 of Set 8 | kruisfontein
# Processing Record 19 of Set 8 | vostok
# Processing Record 20 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 21 of Set 8 | oranjemund
# Processing Record 22 of Set 8 | aswan
# Processing Record 23 of Set 8 | bonavista
# Processing Record 24 of Set 8 | pouembout
# Processing Record 25 of Set 8 | saint anthony
# Processing Record 26 of Set 8 | talnakh
# Processing Record 27 of Set 8 | launceston
# Processing Record 28 of Set 8 | bhinmal
# Processing Record 29 of Set 8 | alice springs
# Processing Record 30 of Set 8 | sao felix do xingu
# Processing Record 31 of Set 8 | kamenka
# Processing Record 32 of Set 8 | mercedes
# Processing Record 33 of Set 8 | guerrero negro
# Processing Record 34 of Set 8 | bursa
# Processing Record 35 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 36 of Set 8 | ketchikan
# Processing Record 37 of Set 8 | saint-pierre
# Processing Record 38 of Set 8 | kailua
# Processing Record 39 of Set 8 | lincoln
# Processing Record 40 of Set 8 | kapoeta
# Processing Record 41 of Set 8 | watertown
# Processing Record 42 of Set 8 | mehamn
# Processing Record 43 of Set 8 | robertsport
# Processing Record 44 of Set 8 | srednekolymsk
# Processing Record 45 of Set 8 | wattegama
# Processing Record 46 of Set 8 | maldonado
# Processing Record 47 of Set 8 | tambura
# Processing Record 48 of Set 8 | tarabuco
# Processing Record 49 of Set 8 | belmonte
# Processing Record 50 of Set 8 | severo-yeniseyskiy
# Processing Record 1 of Set 9 | hofn
# Processing Record 2 of Set 9 | bojnurd
# Processing Record 3 of Set 9 | acarau
# Processing Record 4 of Set 9 | naze
# Processing Record 5 of Set 9 | clyde river
# Processing Record 6 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 9 | edd
# Processing Record 8 of Set 9 | khani
# Processing Record 9 of Set 9 | ipixuna
# Processing Record 10 of Set 9 | brigantine
# Processing Record 11 of Set 9 | dingle
# Processing Record 12 of Set 9 | lata
# Processing Record 13 of Set 9 | arman
# Processing Record 14 of Set 9 | fukue
# Processing Record 15 of Set 9 | tilichiki
# Processing Record 16 of Set 9 | mendeleyevo
# Processing Record 17 of Set 9 | san juan
# Processing Record 18 of Set 9 | nisia floresta
# Processing Record 19 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 20 of Set 9 | lodja
# Processing Record 21 of Set 9 | cherskiy
# Processing Record 22 of Set 9 | camopi
# Processing Record 23 of Set 9 | norman wells
# Processing Record 24 of Set 9 | port saint lucie
# Processing Record 25 of Set 9 | takoradi
# Processing Record 26 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 9 | boa vista
# Processing Record 28 of Set 9 | san policarpo
# Processing Record 29 of Set 9 | alenquer
# Processing Record 30 of Set 9 | gashua
# Processing Record 31 of Set 9 | monywa
# Processing Record 32 of Set 9 | briancon
# Processing Record 33 of Set 9 | sri aman
# Processing Record 34 of Set 9 | at-bashi
# Processing Record 35 of Set 9 | la seyne-sur-mer
# Processing Record 36 of Set 9 | vada
# Processing Record 37 of Set 9 | chinsali
# Processing Record 38 of Set 9 | okhotsk
# Processing Record 39 of Set 9 | lowestoft
# Processing Record 40 of Set 9 | shieli
# Processing Record 41 of Set 9 | san rafael
# Processing Record 42 of Set 9 | puerto narino
# Processing Record 43 of Set 9 | umm kaddadah
# Processing Record 44 of Set 9 | broome
# Processing Record 45 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 9 | kudahuvadhoo
# Processing Record 47 of Set 9 | leningradskiy
# Processing Record 48 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | nanakuli
# Processing Record 1 of Set 10 | sovetskiy
# Processing Record 2 of Set 10 | wilmington
# Processing Record 3 of Set 10 | kupang
# Processing Record 4 of Set 10 | bilibino
# Processing Record 5 of Set 10 | tynda
# Processing Record 6 of Set 10 | demerval lobao
# Processing Record 7 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 10 | buala
# Processing Record 9 of Set 10 | manzhouli
# Processing Record 10 of Set 10 | teya
# Processing Record 11 of Set 10 | mareeba
# Processing Record 12 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 10 | ceska lipa
# Processing Record 14 of Set 10 | lamu
# Processing Record 15 of Set 10 | ola
# Processing Record 16 of Set 10 | ossora
# Processing Record 17 of Set 10 | madang
# Processing Record 18 of Set 10 | impfondo
# Processing Record 19 of Set 10 | kaabong
# Processing Record 20 of Set 10 | manicore
# Processing Record 21 of Set 10 | yar-sale
# Processing Record 22 of Set 10 | verkhnyaya inta
# Processing Record 23 of Set 10 | brazzaville
# Processing Record 24 of Set 10 | tarauaca
# Processing Record 25 of Set 10 | pyaozerskiy
# Processing Record 26 of Set 10 | bijar
# Processing Record 27 of Set 10 | clarence town
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | mongoumba
# Processing Record 30 of Set 10 | mabaruma
# Processing Record 31 of Set 10 | lorengau
# Processing Record 32 of Set 10 | nieuw amsterdam
# Processing Record 33 of Set 10 | bolu
# Processing Record 34 of Set 10 | iskateley
# Processing Record 35 of Set 10 | harwich
# Processing Record 36 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 10 | linares
# Processing Record 38 of Set 10 | concordia
# Processing Record 39 of Set 10 | mount gambier
# Processing Record 40 of Set 10 | marabba
# Processing Record 41 of Set 10 | aksarka
# Processing Record 42 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 10 | buguruslan
# Processing Record 44 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 10 | kaka
# Processing Record 46 of Set 10 | herat
# Processing Record 47 of Set 10 | excelsior springs
# Processing Record 48 of Set 10 | wajima
# Processing Record 49 of Set 10 | uglovka
# Processing Record 50 of Set 10 | urumqi
# Processing Record 1 of Set 11 | mahuva
# Processing Record 2 of Set 11 | pakokku
# Processing Record 3 of Set 11 | namatanai
# Processing Record 4 of Set 11 | pacific grove
# Processing Record 5 of Set 11 | awjilah
# Processing Record 6 of Set 11 | sao filipe
# Processing Record 7 of Set 11 | rudnogorsk
# Processing Record 8 of Set 11 | sarila
# Processing Record 9 of Set 11 | beringovskiy
# Processing Record 10 of Set 11 | marrakesh
# Processing Record 11 of Set 11 | aranos
# Processing Record 12 of Set 11 | ukiah
# Processing Record 13 of Set 11 | nome
# Processing Record 14 of Set 11 | faya
# Processing Record 15 of Set 11 | kayerkan
# Processing Record 16 of Set 11 | wanning
# Processing Record 17 of Set 11 | ganzhou
# Processing Record 18 of Set 11 | barstow
# Processing Record 19 of Set 11 | altamira
# Processing Record 20 of Set 11 | kieta
# Processing Record 21 of Set 11 | opuwo
# Processing Record 22 of Set 11 | udachnyy
# Processing Record 23 of Set 11 | aykhal
# Processing Record 24 of Set 11 | coihaique
# Processing Record 25 of Set 11 | proletariy
# Processing Record 26 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 11 | kano
# Processing Record 28 of Set 11 | okato
# Processing Record 29 of Set 11 | rincon
# Processing Record 30 of Set 11 | araceli
# Processing Record 31 of Set 11 | rawson
# Processing Record 32 of Set 11 | bilma
# Processing Record 33 of Set 11 | ndola
# Processing Record 34 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 11 | egvekinot
# Processing Record 36 of Set 11 | alta floresta
# Processing Record 37 of Set 11 | palmital
# Processing Record 38 of Set 11 | muscat
# Processing Record 39 of Set 11 | semporna
# Processing Record 40 of Set 11 | tartus
# Processing Record 41 of Set 11 | shwebo
# Processing Record 42 of Set 11 | menongue
# Processing Record 43 of Set 11 | la paz
# Processing Record 44 of Set 11 | valparaiso
# Processing Record 45 of Set 11 | ushibuka
# Processing Record 46 of Set 11 | mitchell
# Processing Record 47 of Set 11 | requena
# Processing Record 48 of Set 11 | verkhnevilyuysk
# Processing Record 49 of Set 11 | palmer
# Processing Record 50 of Set 11 | azare
# Processing Record 1 of Set 12 | edelira
# Processing Record 2 of Set 12 | kaeo
# Processing Record 3 of Set 12 | longkou
# Processing Record 4 of Set 12 | pangoa
# Processing Record 5 of Set 12 | french harbor
# Processing Record 6 of Set 12 | cheremshan
# Processing Record 7 of Set 12 | winnemucca
# Processing Record 8 of Set 12 | mahibadhoo
# Processing Record 9 of Set 12 | bosaso
# Processing Record 10 of Set 12 | auki
# Processing Record 11 of Set 12 | mayuge
# Processing Record 12 of Set 12 | aguimes
# Processing Record 13 of Set 12 | neiafu
# Processing Record 14 of Set 12 | xuzhou
# Processing Record 15 of Set 12 | lompoc
# Processing Record 16 of Set 12 | ambilobe
# Processing Record 17 of Set 12 | portales
# Processing Record 18 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 12 | nhulunbuy
# Processing Record 20 of Set 12 | haines junction
# Processing Record 21 of Set 12 | sokode
# Processing Record 22 of Set 12 | douentza
# Processing Record 23 of Set 12 | khandyga
# Processing Record 24 of Set 12 | boca do acre
# Processing Record 25 of Set 12 | brae
# Processing Record 26 of Set 12 | correntina
# Processing Record 27 of Set 12 | jacareacanga
# Processing Record 28 of Set 12 | palm city
# Processing Record 29 of Set 12 | skibbereen
# Processing Record 30 of Set 12 | qasigiannguit
# Processing Record 31 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 12 | nosy varika
# Processing Record 33 of Set 12 | trairi
# Processing Record 34 of Set 12 | la solana
# Processing Record 35 of Set 12 | poum
# Processing Record 36 of Set 12 | kvarkeno
# Processing Record 37 of Set 12 | kilindoni
# Processing Record 38 of Set 12 | wladyslawowo
# Processing Record 39 of Set 12 | oktyabrskoye
# Processing Record 40 of Set 12 | matara
# Processing Record 41 of Set 12 | riyadh
# Processing Record 42 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 12 | mildura
# Processing Record 44 of Set 12 | zuenoula
# Processing Record 45 of Set 12 | san isidro
# Processing Record 46 of Set 12 | ponta delgada
# Processing Record 47 of Set 12 | bandarbeyla
# Processing Record 48 of Set 12 | malindi
# Processing Record 49 of Set 12 | anshun
# Processing Record 50 of Set 12 | rio bueno
# Processing Record 1 of Set 13 | hovd
# Processing Record 2 of Set 13 | comodoro rivadavia
# Processing Record 3 of Set 13 | saint-augustin
# Processing Record 4 of Set 13 | akyab
# Processing Record 5 of Set 13 | florianopolis
# Processing Record 6 of Set 13 | montemor-o-novo
# Processing Record 7 of Set 13 | pombas
# Processing Record 8 of Set 13 | yako
# Processing Record 9 of Set 13 | peniche
# Processing Record 10 of Set 13 | mahad
# Processing Record 11 of Set 13 | sobolevo
# Processing Record 12 of Set 13 | ulaanbaatar
# Processing Record 13 of Set 13 | ilula
# Processing Record 14 of Set 13 | novoagansk
# Processing Record 15 of Set 13 | saint-paul
# Processing Record 16 of Set 13 | san carlos de bariloche
# Processing Record 17 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 18 of Set 13 | puerto escondido
# Processing Record 19 of Set 13 | puksoozero
# Processing Record 20 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 13 | itarema
# Processing Record 22 of Set 13 | houma
# Processing Record 23 of Set 13 | kotido
# Processing Record 24 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 13 | puerto maldonado
# Processing Record 26 of Set 13 | katobu
# Processing Record 27 of Set 13 | bataipora
# Processing Record 28 of Set 13 | vredendal
# Processing Record 29 of Set 13 | aquidauana
# Processing Record 30 of Set 13 | hambantota
# Processing Record 31 of Set 13 | tura
# Processing Record 32 of Set 13 | novobiryusinskiy
# Processing Record 33 of Set 13 | cabedelo
# Processing Record 34 of Set 13 | taoudenni
# Processing Record 35 of Set 13 | tam ky
# Processing Record 36 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 13 | chicama
# Processing Record 38 of Set 13 | bubaque
# Processing Record 39 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 13 | kungurtug
# Processing Record 41 of Set 13 | aguas belas
# Processing Record 42 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 13 | nathdwara
# Processing Record 44 of Set 13 | sao joao da barra
# Processing Record 45 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 46 of Set 13 | honiara
# Processing Record 47 of Set 13 | pitimbu
# Processing Record 48 of Set 13 | acapulco
# Processing Record 49 of Set 13 | waingapu
# Processing Record 50 of Set 13 | guerrero
# Processing Record 1 of Set 14 | manhattan
# Processing Record 2 of Set 14 | conde
# Processing Record 3 of Set 14 | anadyr
# Processing Record 4 of Set 14 | klamath falls
# Processing Record 5 of Set 14 | pandamatenga
# Processing Record 6 of Set 14 | kenai
# Processing Record 7 of Set 14 | shahrud
# Processing Record 8 of Set 14 | mogwase
# Processing Record 9 of Set 14 | lagos
# Processing Record 10 of Set 14 | berezovka
# Processing Record 11 of Set 14 | sindal
# Processing Record 12 of Set 14 | iranshahr
# Processing Record 13 of Set 14 | rio claro
# Processing Record 14 of Set 14 | sangar
# Processing Record 15 of Set 14 | eureka
# Processing Record 16 of Set 14 | kwinana
# Processing Record 17 of Set 14 | yulara
# Processing Record 18 of Set 14 | vila velha
# Processing Record 19 of Set 14 | meadow lake
# Processing Record 20 of Set 14 | jucurutu
# Processing Record 21 of Set 14 | dong hoi
# Processing Record 22 of Set 14 | dawlatabad
# Processing Record 23 of Set 14 | tigil
# Processing Record 24 of Set 14 | hirara
# Processing Record 25 of Set 14 | rowlett
# Processing Record 26 of Set 14 | dalby
# Processing Record 27 of Set 14 | prince rupert
# Processing Record 28 of Set 14 | naantali
# Processing Record 29 of Set 14 | marsh harbour
# Processing Record 30 of Set 14 | sao gabriel da cachoeira
# Processing Record 31 of Set 14 | baykit
# Processing Record 32 of Set 14 | puerto colombia
# Processing Record 33 of Set 14 | dabola
# Processing Record 34 of Set 14 | oksfjord
# Processing Record 35 of Set 14 | sumbawanga
# Processing Record 36 of Set 14 | normandin
# Processing Record 37 of Set 14 | puerto quijarro
# Processing Record 38 of Set 14 | pishin
# Processing Record 39 of Set 14 | port moresby
# Processing Record 40 of Set 14 | dergachi
# Processing Record 41 of Set 14 | katubao
# Processing Record 42 of Set 14 | kathmandu
# Processing Record 43 of Set 14 | simpang
# Processing Record 44 of Set 14 | ulaangom
# Processing Record 45 of Set 14 | nong bua
# Processing Record 46 of Set 14 | maceio
# Processing Record 47 of Set 14 | maniitsoq
# Processing Record 48 of Set 14 | diego de almagro
# Processing Record 49 of Set 14 | quesnel
# Processing Record 50 of Set 14 | taybad
# Processing Record 1 of Set 15 | yarada
# Processing Record 2 of Set 15 | abeche
# Processing Record 3 of Set 15 | dwarka
# Processing Record 4 of Set 15 | maihar
# Processing Record 5 of Set 15 | asfi
# Processing Record 6 of Set 15 | mirabad
# Processing Record 7 of Set 15 | san andres
# Processing Record 8 of Set 15 | semnan
# Processing Record 9 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 15 | kathu
# Processing Record 11 of Set 15 | general roca
# Processing Record 12 of Set 15 | vetlanda
# Processing Record 13 of Set 15 | alofi
# Processing Record 14 of Set 15 | richards bay
# Processing Record 15 of Set 15 | el faiyum
# City not found. Skipping...
# Processing Record 16 of Set 15 | eston
# Processing Record 17 of Set 15 | yashkino
# Processing Record 18 of Set 15 | tzimol
# Processing Record 19 of Set 15 | siverek
# Processing Record 20 of Set 15 | russell
# Processing Record 21 of Set 15 | canico
# Processing Record 22 of Set 15 | envira
# Processing Record 23 of Set 15 | novo aripuana
# Processing Record 24 of Set 15 | mantua
# Processing Record 25 of Set 15 | tara
# Processing Record 26 of Set 15 | terney
# Processing Record 27 of Set 15 | zhob
# Processing Record 28 of Set 15 | quatre cocos
# Processing Record 29 of Set 15 | odoyev
# Processing Record 30 of Set 15 | filingue
# Processing Record 31 of Set 15 | karachi
# Processing Record 32 of Set 15 | chauk
# Processing Record 33 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 15 | cangucu
# Processing Record 35 of Set 15 | hayden
# Processing Record 36 of Set 15 | tias
# Processing Record 37 of Set 15 | kadyy
# Processing Record 38 of Set 15 | yenangyaung
# Processing Record 39 of Set 15 | bambanglipuro
# Processing Record 40 of Set 15 | sambava
# Processing Record 41 of Set 15 | kirakira
# Processing Record 42 of Set 15 | soe
# Processing Record 43 of Set 15 | alcains
# Processing Record 44 of Set 15 | kendrapara
# Processing Record 45 of Set 15 | tosno
# Processing Record 46 of Set 15 | gaogou
# Processing Record 47 of Set 15 | adrar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo      US  19.7297 -155.0900     77.25        80          55
# 1  Chilakalurupet      IN  16.0833   80.1667     77.63        92          41
# 2    Punta Arenas      CL -53.1500  -70.9167     46.51        93         100
# 3           Ancud      CL -41.8697  -73.8203     53.22        88          95
# 4            Aksu      CN  41.1231   80.2644     46.26        53          75
# 5         Mataura      NZ -46.1927  168.8643     61.84        66          24
# 6    Puerto Ayora      EC  -0.7393  -90.3518     80.56        78          61
# 7          Hobart      AU -42.8794  147.3294     63.27        86          20
# 8          Castro      BR -24.7911  -50.0119     64.00        95          96
# 9          Albany      US  42.6001  -73.9662     45.03        87          97
#
#    Wind Speed Current Description
# 0        4.00       broken clouds
# 1        4.38    scattered clouds
# 2       11.50          light rain
# 3        8.66          light rain
# 4        3.53       broken clouds
# 5        0.83          few clouds
# 6        8.95          light rain
# 7        4.61          few clouds
# 8        4.32     overcast clouds
# 9        1.99       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
